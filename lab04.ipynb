# %% [markdown]
# # AGH Modelling of Physical Systems Lab 4 (2025 March 25th)
# Sylwester Arabas (sylwester.arabas@agh.edu.pl)

# %% [markdown]
# **1. diffusion PDE**
#
# Let's introduce a few symbols:
# * ${\color{red}t}$: time
# * ${\color{blue}x}$: physical coordinate (e.g., distance or altitude)
# * ${\color{green}\psi}({\color{blue}x})$: scalar field (e.g., pollutant concentration)
#
# Transport of $\color{green}\psi$ due to diffusion with consant coefficient $\color{orange}\mu$ can be modelled with the diffusion equation:
# $$ \partial_{\color{red} t} {\color{green}\psi} - {\color{orange}\mu} \partial^2_{\color{blue}x}{\color{green}\psi}= 0 $$
#
# For the special case of domain of length $L$ and initial condition ${\color{green}\psi}({\color{red} t}=0,{\color{blue}x}) = \sin(\pi {\color{blue}x} / L)$, an analytical solution is readily available:
# $$ {\color{green}\psi}({\color{blue}x}, {\color{red}t})=e^{-\mu (\pi/L)^2 {\color{red} t}} \sin(\pi {\color{blue}x} / L)$$
#
# Let's depict the problem using NumPy and matplotlib:

# %%
import numpy as np
from matplotlib import pyplot
from matplotlib import pyplot as plt
from open_atmos_jupyter_utils import show_plot, show_anim
from collections.abc import Callable

# %%
class PsiAnalytic:
    def __init__(self, *, mu, L):
        self.mu = mu
        self.L = L
    def __call__(self, *, x, t):
        return np.exp(-self.mu * (np.pi / self.L)**2 * t) * np.sin(np.pi / self.L * x)

# %%
psi_analytic = PsiAnalytic(mu=.5, L=10)
nx = 64
x, dx = np.linspace(0, psi_analytic.L, nx, endpoint=True, retstep=True)
x = x[:-1] + dx/2
t_max = 10

# %%
pyplot.plot(x, psi_analytic(x=x,t=0), label='initial')

for i in range(1, 5):
    pyplot.plot(x, psi_analytic(x=x,t=t_max * i), label=f'analytical at {t_max=}')
pyplot.legend()
pyplot.grid()
show_plot('analytic.pdf')
# Out:
# HBox(children=(HTML(value="<a href='.\\analytic.pdf' target='_blank'>.\\analytic.pdf</a><br>"), HTML(value="<a…

# %% [markdown]
# **2. overview of applications**
#
# * diffusion of heat
# * diffusion of pollutants in atmosphere and hydrosphere
# * diffusion of moisture away from evaporating rain drops
# * diffusion of in PDE originating from SDE in mathematical finance (market volatility)
# * ...

# %% [markdown]
# **3. simple numerical solution using the "upwind" scheme coded in Python**
#
# Diffusion can be expressed in terms of advective fluxes:
#
# $$ \partial_t {\color{green}\psi} +\partial_x \big(\, \underbrace{-\mu \frac{\partial_x {\color{green}\psi}}{{\color{green}\psi}}}_{u} \psi \big) = 0$$
#
# hence we can leverage the basic [**upwind**](https://en.wikipedia.org/wiki/Upwind_scheme) solver to numerically integrate the diffusion equation:
#
# * ${\color{red}n} = \frac{\color{red}t}{\Delta t} \in 0, 1, \ldots$
# * ${\color{blue}i} = \frac{\color{blue}x}{\Delta x} \in 0, 1, \ldots$
# * ${\color{brown}C} = {\color{brown}u}\frac{\Delta t}{\Delta x}$ (so called Courant number)
# * ${\color{green}\psi}_{\color{blue}i}^{\color{red}n}$: scalar field at "grid cell" $\color{blue}i$ in space at time "level" ${\color{red}n}$
#
#
# $$
#   {\color{green}\psi}^{{\color{red}n}+1}_{\color{blue}i} = {\color{green}\psi}^{\color{red}n}_{\color{blue}i} - \left[F\left({\color{green}\psi}^{\color{red}n}_{\color{blue}i},  {\color{green}\psi}^{\color{red}n}_{{\color{blue}i}+1}, {\color{brown}C_{i+1/2}^{\color{red}n}}\right)-F\left({\color{green}\psi}^{\color{red}n}_{{\color{blue}i}-1},{\color{green}\psi}^{\color{red}n}_{\color{blue}i}, {\color{brown}C_{i-1/2}^{\color{red}n}}\right)\right]
# $$
# $$F(\psi_L, \psi_R, C)=\frac{C+|C|}{2}\psi_L + \frac{C-|C|}{2}\psi_R$$
#
# with:
#
# $$C_{{\color{blue}i}-1/2}=\frac{\Delta t}{\Delta x}u_{{\color{blue}i}-1/2}=-\mu\frac{\Delta t}{\Delta x}\frac{{\color{green}\psi}_{\color{blue}i}-{\color{green}\psi}_{{\color{blue}i}-1}}{\Delta x}\frac{2}{{\color{green}\psi}_{{\color{blue}i}}+{\color{green}\psi}_{{\color{blue}i}-1}}$$

# %% [markdown]
# **4. upwind algorithm coded in Python/NumPy: functions and a useful structure**

# %%
def F(psi_l, psi_r, C):
    return .5 * (C + abs(C)) * psi_l + \
           .5 * (C - abs(C)) * psi_r

class Shift:
    def __init__(self, add: int, sub: int):
        self.add_val = add
        self.sub_val = sub

    def __radd__(self, other: slice) -> slice:
        return slice(other.start + self.add_val, other.stop + self.add_val, other.step)
    
    def __rsub__(self, other: slice) -> slice:
        return slice(other.start - self.sub_val, other.stop - self.sub_val, other.step)

# %% [markdown]
# **5. upwind algorithm coded in Python/NumPy: data/objects**

# %%
one = Shift(add=1, sub=1)
hlf = Shift(add=0, sub=1)

nt = 500
dt = t_max / nt

i = slice(1, nx-2)
im = slice(1, nx-1)

# %% [markdown]
# **6. upwind algorithm coded in Python/NumPy: time-stepping loop**

# %%
psi = psi_analytic(x=x, t=0)
C = np.zeros(len(psi) - 1)
output = [psi.copy()]
for _ in range(nt + 1):
    C[im - hlf] = -2.0 * psi_analytic.mu * dt / (dx * dx) * (psi[im] - psi[im - one]) / (psi[im] + psi[im - one])
    assert max(abs(C)) <= 1
    psi[i] -= F(psi[i], psi[i + one], C[i + hlf]) - F(psi[i - one], psi[i], C[i - hlf])
    output += [psi.copy()]

# %% [markdown]
# **7. comparing analytic and numerical solutions**

# %%
def plot(step):
    fig = pyplot.figure()
    pyplot.step(x, psi_analytic(x=x, t=0), label='initial (discretised)', where='mid')
    pyplot.step(x, psi_analytic(x=x, t=step*dt), label='analytical (discretised)', where='mid')
    pyplot.step(x, output[step], label=f'numerical (upwind) t/t_max={step}', where='mid')
    pyplot.legend()
    pyplot.grid()
    return fig 
plot(nt)
show_plot('numeric.pdf')
# Out:
# HBox(children=(HTML(value="<a href='.\\numeric.pdf' target='_blank'>.\\numeric.pdf</a><br>"), HTML(value="<a h…

# %% [markdown]
# **8. animation**

# %%
show_anim(plot, range(0, nt, 3))
# Out:
# <img src="data:image/gif;base64,..." />
# HTML(value="<a href='.\\tmpr0y9o1go.gif' target='_blank'>.\\tmpr0y9o1go.gif</a><br>")

# %%
def concentration_analytical(x: np.ndarray, t: float, M: float, D: float, u: float) -> np.ndarray:
    return M / np.sqrt(4 * np.pi * D * t) * np.exp(- (x - u * t)**2 / (4 * D * t))

# %%
x_min = -2
x_max = 4
nx = 700
x = np.linspace(x_min, x_max, nx, endpoint=False)
dx = (x_max - x_min) / nx

M = 0.01
D = 0.01
u = 0.5

# %%
t_start = 0.3
t_end = 5.0

nt = 2400
dt = (t_end - t_start) / nt

# %%
psi_init = concentration_analytical(x, t_start, M, D, u)

# %%
plt.plot(x, psi_init, label='initial')
show_plot()
# Out:
# HBox(children=(HTML(value="<a href='.\\tmpcjx3kpq9.pdf' target='_blank'>.\\tmpcjx3kpq9.pdf</a><br>"), HTML(val…

# %%
i = slice(1, nx-1)
im = slice(1, nx)

# %%
psi = psi_init.copy()
C = np.zeros(len(psi) - 1)
output = [psi.copy()]
for index in range(nt + 1):
    C[im - hlf] = dt / dx * (u - 2.0 * D / dx * np.minimum(np.nan_to_num((psi[im] - psi[im - one]) / (psi[im] + psi[im - one]), nan=0.0), 1.0))
    assert max(abs(C)) <= 1, f'{max(abs(C))=}, {index=}'
    psi[i] -= F(psi[i], psi[i + one], C[i + hlf]) - F(psi[i - one], psi[i], C[i - hlf])
    output += [psi.copy()]
# Out:
# C:\Users\piotr\AppData\Local\Temp\ipykernel_16352\4032995505.py:5: RuntimeWarning: invalid value encountered in divide
#   C[im - hlf] = dt / dx * (u - 2.0 * D / dx * np.minimum(np.nan_to_num((psi[im] - psi[im - one]) / (psi[im] + psi[im - one]), nan=0.0), 1.0))

# %%
def rmse(x: np.ndarray, y: np.ndarray) -> float:
    return np.sqrt(np.mean((x - y)**2))

# %%
def plot_general(step: int, analytic_func: Callable[[float], np.ndarray], numerical_func: Callable[[int], np.ndarray], start_time: float, rmse_dict: dict[int, float]) -> plt.Figure:
    fig = pyplot.figure()

    analytical = analytic_func(step*dt + start_time)
    numerical = numerical_func(step)
    rmse_val = rmse(analytical, numerical)
    rmse_dict[step] = rmse_val
    
    pyplot.title(f't={step*dt+start_time:.2f}, RMSE={rmse_val:.2e}')
    pyplot.step(x, analytic_func(start_time), label='initial (discretised)', where='mid')
    pyplot.step(x, analytical, label='analytical (discretised)', where='mid')
    pyplot.step(x, numerical, label=f'numerical (upwind) t/dt={step}', where='mid')
    pyplot.legend()
    pyplot.grid()
    return fig

# %%
rmse_dict = {}
plot_adv_diff = lambda step: plot_general(step, lambda t: concentration_analytical(x, t, M, D, u), lambda step: output[step], t_start, rmse_dict)
plot_adv_diff(nt)

# %%
show_anim(plot_adv_diff, range(0, nt, 10))
# Out:
# <img src="data:image/gif;base64,..." />
# HTML(value="<a href='.\\tmpow7s2nm4.gif' target='_blank'>.\\tmpow7s2nm4.gif</a><br>")

# %%
rmse_all = list(rmse_dict.items())
rmse_all.sort(key=lambda x: x[0])

plt.plot([x[0] for x in rmse_all], [x[1] for x in rmse_all])
plt.xlabel('time step')
plt.ylabel('RMSE')
plt.grid()
show_plot()
# Out:
# HBox(children=(HTML(value="<a href='.\\tmpczjajhfn.pdf' target='_blank'>.\\tmpczjajhfn.pdf</a><br>"), HTML(val…
